# %%
import pandas as pd
whoiswho = pd.read_csv("cross-verified-database.csv", encoding='utf-8')

# %%
occupations = pd.DataFrame(whoiswho.groupby("level3_main_occ")["name"].nunique()).rename(columns={"name": "count"})
all_occ = whoiswho["level3_main_occ"].drop_duplicates().to_list()
top_occ = whoiswho.groupby("level3_main_occ")["name"].nunique().nlargest(100)
top_occ = top_occ.index.to_list()

# %%
occupations.sort_values(by="count",ascending=False)
# Out:
#                   count
# level3_main_occ
# politician       270431
# football         250439
# actor            121761
# writer            74709
# painter           60175
# ...                 ...
# fakultet              1
# modèle                1
# facteur               1
# expédition            1
# überwachung           1
#
# [4985 rows x 1 columns]

# %% [markdown]
# There are almost 5,000 unique occupations listed as the main occupation, the most common being politician, football (…player, …coach etc.) and actor.

# %%
pd.DataFrame(whoiswho[whoiswho.level3_main_occ.isin(top_occ)].groupby("level3_main_occ")["birth"].nunique().sort_values(ascending=False))
# Out:
#                     birth
# level3_main_occ
# politician           1545
# priest               1254
# poet                 1145
# aristocrat           1025
# king                  962
# ...                   ...
# judo                  116
# presenter             111
# canoe                 108
# handball              100
# computer_scientist     97
#
# [100 rows x 1 columns]

# %% [markdown]
# Of the 100 most frequently listed occupation, politicians have the longest time span, with a notable politician being born in 1545 disctinct years. On the tail: computer scientists and sportspeople.

# %% [markdown]
# ## Human Swiss army knives

# %% [markdown]
# Let's find the people with the highest number of listed occupations.

# %%
def nicerOccupations(x):
    x = x.replace("D:_","")
    x = x.split("P:")[0].split("_")
    for y in x:
        if len(y) < 2:
            x.remove(y)
    return x

# %%
whoiswho["all_occ"] = whoiswho["level3_all_occ"].apply(nicerOccupations)

# %%
whoiswho["no_occ"] = whoiswho["all_occ"].apply(lambda x: len(x))

# %%
whoiswho[["name","no_occ","all_occ"]].sort_values(by="no_occ",ascending=False).head(20)
# Out:
#                                name  no_occ  \
# 1336243  Johann_Wolfgang_von_Goethe      30
# 21862                B._R._Ambedkar      26
# 598608              Nikolai_Fomenko      24
# 369289            Andrey_Makarevich      23
# 12936         Madonna_(entertainer)      21
# 485               Benjamin_Franklin      21
# 7302         Alexander_von_Humboldt      20
# 2244795            Alexandra_Jacobi      19
# 8463                     Boris_Vian      19
# 143827                     Shen_Kuo      19
# 551361                 Donald_Trump      19
# 964                    Dolly_Parton      18
# 1854452                  Misako_Uno      18
# 255903                Russell_Brand      18
# 7153              Justin_Timberlake      17
# 1802785              Gennady_Vetrov      17
# 32293                     Al-Biruni      17
# 13295            Christina_Aguilera      17
# 34344                  Maya_Angelou      17
# 1417258                 Nicki_Minaj      17
#
#                                                    all_occ
# 1336243  [poet, theatre, botanist, politician, painter,...
# 21862    [economist, politician, essayist, lawyer, juri...
# 598608   [singer, comedian, music, presenter, radio, sk...
# 369289   [singer, poet, composer, presenter, actor, arc...
# 12936    [singer, actor, film, composer, film, writer, ...
# 485      [writer, politician, publisher, printer, theor...
# 7302     [geologist, explorer, botanist, geographer, ge...
# 2244795  [man, of, letters, correspondent, journalist, ...
# 8463     [polymath, singer, poet, trumpet, lyricist, pa...
# 143827   [physicist, cartographer, mathematician, astro...
# 551361   [magnate, investor, restaurateur, writer, entr...
# 964      [guitar, singer, actor, singer, artist, banjoi...
# 1854452  [vocalist, dancer, essayist, producer, designe...
# 255903   [actor, columnist, comedian, presenter, film, ...
# 7153     [actor, film, music, dancer, actor, entreprene...
# 1802785  [writer, satirist, comedian, comedian, singer,...
# 32293    [philosopher, chemist, geographer, polymath, m...
# 13295    [singer, singer, composer, dancer, music, prod...
# 34344    [poet, comedian, dancer, film, producer, playw...
# 1417258  [composer, actor, singer, actor, entrepreneur,...

# %% [markdown]
# No surprise here.

# %% [markdown]
# ## No (wo)men allowed

# %% [markdown]
# There are two ways to identify the professions with the largest gender gap. First we can simply take a look at the ratio of both genders. Second, we can list the most frequent occupations performed by 0 notable women or men.

# %%
occ_total_men = pd.Series(whoiswho[whoiswho["gender"] == "Male"].groupby(["level3_main_occ"]).size(), name="occ_total_men")
whoiswho = whoiswho.merge(occ_total_men, on = ["level3_main_occ"], how = "outer")
occ_total_women = pd.Series(whoiswho[whoiswho["gender"] == "Female"].groupby(["level3_main_occ"]).size(), name="occ_total_women")
whoiswho = whoiswho.merge(occ_total_women, on = ["level3_main_occ"], how = "outer")

# %%
whoiswho["gender_ratio"] = whoiswho["occ_total_men"] / whoiswho["occ_total_women"]

# %%
pd.DataFrame(whoiswho.groupby("level3_main_occ")["gender_ratio"].first().nlargest(10))
# Out:
#                  gender_ratio
# level3_main_occ
# prelate           3900.000000
# leutnant           847.000000
# organbuilder       758.000000
# samurai            714.000000
# landrat            711.000000
# theologe           522.000000
# rikishi            259.500000
# gallantry          223.000000
# katholischer       220.333333
# bischof            218.000000

# %%
pd.DataFrame(whoiswho.groupby("level3_main_occ")["gender_ratio"].first().nsmallest(10))
# Out:
#                  gender_ratio
# level3_main_occ
# netball              0.006135
# nun                  0.006986
# camogie              0.008097
# actress              0.009036
# beauty_pageant       0.010462
# feminist             0.013025
# abbess               0.013158
# mistress             0.016529
# wife_of              0.018587
# first_lady           0.018868

# %%
pd.DataFrame(whoiswho[whoiswho["occ_total_men"].isnull()].groupby("level3_main_occ").size().nlargest(5))
# Out:
#                    0
# level3_main_occ
# schermitrice     149
# nobildonna       146
# salonnière        86
# suffragist        76
# principessa       64

# %%
pd.DataFrame(whoiswho[whoiswho["occ_total_women"].isnull()].groupby("level3_main_occ").size().nlargest(5))
# Out:
#                     0
# level3_main_occ
# hurler           1989
# generalmajor     1323
# flying_ace        905
# geheimrat         428
# adliger           344

# %%
occ_total = pd.Series(whoiswho.groupby(["level3_main_occ"]).size(), name="occ_total")
whoiswho = whoiswho.merge(occ_total, on = ["level3_main_occ"], how = "outer")

# %% [markdown]
# ## Regionally specific occupations

# %%
whoiswho[whoiswho["occ_total"] > 300].groupby("level3_main_occ")["un_subregion"].nunique().nsmallest(25)
# Out:
# level3_main_occ
# gaelic_football         1
# révolution_française    2
# hurler                  3
# samurai                 3
# kloster                 4
# lacrosse                4
# seiyū                   4
# ämbetsman               4
# earl                    5
# geheimrat               5
# graf                    5
# nascar                  5
# organbuilder            5
# résistant               5
# abt                     6
# landrat                 6
# nobile                  6
# troubadour              6
# adliger                 7
# nobre                   7
# romanist                7
# feudatory               8
# fiddler                 8
# germanist               8
# goldsmith               8
# Name: un_subregion, dtype: int64

# %% [markdown]
# The [Gaelic football](https://en.wikipedia.org/wiki/Gaelic_football) is mentioned in the data of more than 300 notable individuals, all coming from a single subregion.

# %% [markdown]
# ## My profession is X. Give me some side job ideas!

# %%
def side_occ(occupation, frame):
    side_occ_raw = []
    side_occ = {}
    whoiswho_filtered = frame[frame["level3_main_occ"] == occupation]
    combinations = whoiswho_filtered["all_occ"].to_list()
    for x in combinations:
        for y in x:
            if y != occupation:
                side_occ_raw.append(y)
    for x in side_occ_raw:
        count = side_occ_raw.count(x)
        side_occ[count] = x
    side_occ = pd.DataFrame.from_dict(side_occ, orient="index", columns=["second_occupation"]).sort_index(ascending=False)
    return(side_occ)

# %%
side_occ("architect", whoiswho).head(60)
# Out:
#     second_occupation
# 673          academic
# 475          engineer
# 469           planner
# 324           painter
# 237          designer
# 160        politician
# 153          sculptor
# 124            writer
# 84          historian
# 73                art
# 69             artist
# 64         journalist
# 59           restorer
# 51          professor
# 26       photographer
# 24          education
# 23            teacher
# 22       entrepreneur
# 21      draughtswoman
# 18            militar
# 17             author
# 16           gardener
# 14       scenographer
# 13             editor
# 11               poet
# 10             critic
# 9             curator
# 8           publisher
# 7            surveyor
# 6          production
# 5          stonemason
# 4             fighter
# 3           physician
# 2               rower
# 1            feminist

# %% [markdown]
# ## Relations between specific fields and professions

# %%
level2occs = whoiswho["level2_main_occ"].drop_duplicates().to_list()
level2occs.remove("Missing")
level2occs = sorted(level2occs)
level2_main_occ = {}
for occupation in level2occs:
    level2filtered = whoiswho[whoiswho["level2_main_occ"] == occupation]
    total = level2filtered.shape[0]
    row = {}
    
    for secondoccupation in level2occs:
        level2doublefiltered = level2filtered[level2filtered["level2_second_occ"] == secondoccupation]
        partial = level2doublefiltered.shape[0]
        ratio = partial / total
        row[secondoccupation] = ratio
    
    level2_main_occ[occupation] = row
level2_main_occ = pd.DataFrame(level2_main_occ).sort_index()
level2_main_occ.style.background_gradient(axis=None, cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_08b6e_row0_col0, #T_08b6e_row1_col1, #T_08b6e_row2_col2, #T_08b6e_row3_col3, #T_08b6e_row4_col4, #T_08b6e_row5_col5, #T_08b6e_row6_col6, #T_08b6e_row7_col7, #T_08b6e_row8_col8, #T_08b6e_row9_col9, #T_08b6e_row10_col10, #T_08b6e_row11_col11, #T_08b6e_row12_col12, #T_08b6e_row13_col13 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_08b6e_row0_col1, #T_08b6e_row5_col2, #T_08b6e_row13_col10 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_08b6e_row0_col2, #T_08b6e_row2_col4, #T_08b6e_row5_col13, #T_08b6e_row6_col11 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_08b6e_row0_col3 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_08b6e_row0_col4, #T_08b6e_row2_col9, #T_08b6e_row10_col0 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_08b6e_row0_col5 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_08b6e_row0_col6, #T_08b6e_row5_col0, #T_08b6e_row6_col7 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_08b6e_row0_col7, #T_08b6e_row0_col9, #T_08b6e_row6_col5, #T_08b6e_row13_col3 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_08b6e_row0_col8, #T_08b6e_row1_col3, #T_08b6e_row7_col3, #T_08b6e_row7_col12, #T_08b6e_row8_col4, #T_08b6e_row8_col5, #T_08b6e_row9_col12, #T_08b6e_row11_col5, #T_08b6e_row12_col1 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_08b6e_row0_col10, #T_08b6e_row7_col6 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_08b6e_row0_col11 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_08b6e_row0_col12, #T_08b6e_row4_col7, #T_08b6e_row5_col3, #T_08b6e_row8_col3, #T_08b6e_row12_col0 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_08b6e_row0_col13 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_08b6e_row1_col0, #T_08b6e_row1_col13, #T_08b6e_row5_col7, #T_08b6e_row12_col2 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_08b6e_row1_col2, #T_08b6e_row13_col7 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_08b6e_row1_col4, #T_08b6e_row3_col8, #T_08b6e_row6_col0, #T_08b6e_row9_col10 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_08b6e_row1_col5, #T_08b6e_row5_col4, #T_08b6e_row5_col6, #T_08b6e_row8_col2, #T_08b6e_row10_col3, #T_08b6e_row13_col1 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_08b6e_row1_col6, #T_08b6e_row1_col8, #T_08b6e_row6_col3, #T_08b6e_row6_col4, #T_08b6e_row7_col13, #T_08b6e_row8_col1, #T_08b6e_row8_col10, #T_08b6e_row9_col8, #T_08b6e_row11_col13 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_08b6e_row1_col7, #T_08b6e_row4_col2, #T_08b6e_row7_col2 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_08b6e_row1_col9, #T_08b6e_row7_col10, #T_08b6e_row9_col2, #T_08b6e_row13_col4 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_08b6e_row1_col10 {
#   background-color: #fec15d;
#   color: #000000;
# }
# #T_08b6e_row1_col11, #T_08b6e_row2_col0, #T_08b6e_row2_col1, #T_08b6e_row3_col7, #T_08b6e_row4_col9, #T_08b6e_row9_col11 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_08b6e_row1_col12, #T_08b6e_row8_col12, #T_08b6e_row12_col8, #T_08b6e_row12_col11 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_08b6e_row2_col3, #T_08b6e_row9_col3 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_08b6e_row2_col5 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_08b6e_row2_col6, #T_08b6e_row3_col1, #T_08b6e_row8_col11, #T_08b6e_row12_col5 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_08b6e_row2_col7, #T_08b6e_row3_col10, #T_08b6e_row7_col0, #T_08b6e_row11_col9, #T_08b6e_row12_col7, #T_08b6e_row13_col11 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_08b6e_row2_col8, #T_08b6e_row4_col12, #T_08b6e_row8_col0, #T_08b6e_row10_col12, #T_08b6e_row11_col1, #T_08b6e_row11_col7, #T_08b6e_row12_col10, #T_08b6e_row13_col12 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_08b6e_row2_col10, #T_08b6e_row3_col9, #T_08b6e_row7_col9, #T_08b6e_row9_col7, #T_08b6e_row10_col4 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_08b6e_row2_col11, #T_08b6e_row4_col8, #T_08b6e_row5_col1, #T_08b6e_row5_col8, #T_08b6e_row5_col11, #T_08b6e_row5_col12, #T_08b6e_row11_col2, #T_08b6e_row11_col12 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_08b6e_row2_col12, #T_08b6e_row3_col12, #T_08b6e_row5_col9, #T_08b6e_row5_col10, #T_08b6e_row6_col1, #T_08b6e_row7_col4 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_08b6e_row2_col13 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_08b6e_row3_col0, #T_08b6e_row3_col13, #T_08b6e_row10_col13 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_08b6e_row3_col2, #T_08b6e_row3_col11, #T_08b6e_row10_col11, #T_08b6e_row13_col0 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_08b6e_row3_col4 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_08b6e_row3_col5, #T_08b6e_row10_col5 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_08b6e_row3_col6 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_08b6e_row4_col0, #T_08b6e_row7_col1, #T_08b6e_row9_col4 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_08b6e_row4_col1, #T_08b6e_row4_col6, #T_08b6e_row9_col0, #T_08b6e_row11_col3, #T_08b6e_row11_col4, #T_08b6e_row11_col10, #T_08b6e_row12_col9, #T_08b6e_row13_col8 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_08b6e_row4_col3 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_08b6e_row4_col5, #T_08b6e_row6_col2, #T_08b6e_row6_col13, #T_08b6e_row11_col6 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_08b6e_row4_col10, #T_08b6e_row8_col13, #T_08b6e_row12_col4 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_08b6e_row4_col11, #T_08b6e_row6_col12, #T_08b6e_row12_col3, #T_08b6e_row12_col6, #T_08b6e_row12_col13 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_08b6e_row4_col13 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_08b6e_row6_col8 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_08b6e_row6_col9 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_08b6e_row6_col10, #T_08b6e_row9_col5 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_08b6e_row7_col5 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_08b6e_row7_col8 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_08b6e_row7_col11, #T_08b6e_row9_col1, #T_08b6e_row11_col8 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_08b6e_row8_col6 {
#   background-color: #cd0b22;
#   color: #f1f1f1;
# }
# #T_08b6e_row8_col7 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_08b6e_row8_col9 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_08b6e_row9_col6, #T_08b6e_row9_col13, #T_08b6e_row13_col6 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_08b6e_row10_col1 {
#   background-color: #9b0026;
#   color: #f1f1f1;
# }
# #T_08b6e_row10_col2 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_08b6e_row10_col6 {
#   background-color: #feb54f;
#   color: #000000;
# }
# #T_08b6e_row10_col7 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_08b6e_row10_col8, #T_08b6e_row13_col5 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_08b6e_row10_col9 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_08b6e_row11_col0 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_08b6e_row13_col2 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_08b6e_row13_col9 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# </style>
# <table id="T_08b6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08b6e_level0_col0" class="col_heading level0 col0" >Academia</th>
#       <th id="T_08b6e_level0_col1" class="col_heading level0 col1" >Administration/Law</th>
#       <th id="T_08b6e_level0_col2" class="col_heading level0 col2" >Corporate/Executive/Business (large)</th>
#       <th id="T_08b6e_level0_col3" class="col_heading level0 col3" >Culture-core</th>
#       <th id="T_08b6e_level0_col4" class="col_heading level0 col4" >Culture-periphery</th>
#       <th id="T_08b6e_level0_col5" class="col_heading level0 col5" >Explorer/Inventor/Developer</th>
#       <th id="T_08b6e_level0_col6" class="col_heading level0 col6" >Family</th>
#       <th id="T_08b6e_level0_col7" class="col_heading level

# %% [markdown]
# (Vertical axis: main occupation, horizontal axis: second occupation.)

# %%
def correlation(frame, size):
    top = frame.groupby("level3_main_occ")["name"].nunique().nlargest(size)
    top = top.index.to_list()
    top = sorted(top)
    matrix = {}
    
    for occupation in top:
    
        whoiswho_filtered = frame[frame["level3_main_occ"] == occupation]
        total = whoiswho_filtered.shape[0]
        combinations = whoiswho_filtered["all_occ"].to_list()
    
        side_occ_raw = []
    
        for x in combinations:
            for y in x:
                if y in top:
                    side_occ_raw.append(y)
    
        row = {}
        side_occ_raw = sorted(side_occ_raw)
        
        notanymore = []
        
        for x in side_occ_raw:
            if x not in notanymore:
                count = side_occ_raw.count(x)
                ratio = count / total
                row[x] = ratio
                notanymore.append(x)
    
        matrix[occupation] = row
    
    matrix = pd.DataFrame(matrix).sort_index()
    
    return(matrix.style.background_gradient(axis=None, cmap='YlOrRd'))

# %%
correlation(whoiswho[(whoiswho["level2_main_occ"] != "Sports/Games")], 11)
# Out:
# <style type="text/css">
# #T_6cc36_row0_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_6cc36_row0_col1, #T_6cc36_row0_col10, #T_6cc36_row3_col5, #T_6cc36_row7_col10, #T_6cc36_row10_col5, #T_6cc36_row10_col8 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_6cc36_row0_col2 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_6cc36_row0_col3, #T_6cc36_row0_col4, #T_6cc36_row0_col6, #T_6cc36_row0_col7, #T_6cc36_row0_col8, #T_6cc36_row1_col3, #T_6cc36_row1_col4, #T_6cc36_row1_col6, #T_6cc36_row1_col7, #T_6cc36_row1_col8, #T_6cc36_row1_col10, #T_6cc36_row2_col4, #T_6cc36_row2_col6, #T_6cc36_row2_col7, #T_6cc36_row2_col8, #T_6cc36_row2_col9, #T_6cc36_row3_col0, #T_6cc36_row3_col1, #T_6cc36_row3_col6, #T_6cc36_row3_col8, #T_6cc36_row3_col9, #T_6cc36_row4_col0, #T_6cc36_row4_col1, #T_6cc36_row4_col2, #T_6cc36_row4_col3, #T_6cc36_row4_col5, #T_6cc36_row4_col6, #T_6cc36_row4_col8, #T_6cc36_row4_col9, #T_6cc36_row4_col10, #T_6cc36_row5_col3, #T_6cc36_row5_col4, #T_6cc36_row5_col6, #T_6cc36_row5_col7, #T_6cc36_row5_col8, #T_6cc36_row6_col0, #T_6cc36_row6_col1, #T_6cc36_row6_col3, #T_6cc36_row6_col4, #T_6cc36_row6_col5, #T_6cc36_row6_col7, #T_6cc36_row6_col8, #T_6cc36_row6_col9, #T_6cc36_row7_col0, #T_6cc36_row7_col1, #T_6cc36_row7_col2, #T_6cc36_row7_col5, #T_6cc36_row7_col6, #T_6cc36_row7_col9, #T_6cc36_row8_col0, #T_6cc36_row8_col1, #T_6cc36_row8_col2, #T_6cc36_row8_col3, #T_6cc36_row8_col4, #T_6cc36_row8_col5, #T_6cc36_row8_col6, #T_6cc36_row8_col7, #T_6cc36_row8_col9, #T_6cc36_row8_col10, #T_6cc36_row9_col2, #T_6cc36_row9_col3, #T_6cc36_row9_col4, #T_6cc36_row9_col6, #T_6cc36_row9_col7, #T_6cc36_row9_col8, #T_6cc36_row9_col10 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6cc36_row0_col5, #T_6cc36_row3_col7, #T_6cc36_row7_col3, #T_6cc36_row10_col0, #T_6cc36_row10_col1, #T_6cc36_row10_col6 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_6cc36_row0_col9 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_6cc36_row1_col0, #T_6cc36_row1_col2, #T_6cc36_row2_col3, #T_6cc36_row2_col5, #T_6cc36_row2_col10, #T_6cc36_row5_col0, #T_6cc36_row5_col2, #T_6cc36_row5_col10, #T_6cc36_row6_col2, #T_6cc36_row6_col10, #T_6cc36_row7_col8, #T_6cc36_row10_col7, #T_6cc36_row10_col9 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_6cc36_row1_col1 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_6cc36_row1_col5, #T_6cc36_row1_col9 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_6cc36_row2_col0, #T_6cc36_row2_col1, #T_6cc36_row9_col1 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_6cc36_row2_col2 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_6cc36_row3_col2, #T_6cc36_row3_col4, #T_6cc36_row10_col4 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_6cc36_row3_col3, #T_6cc36_row5_col5 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_6cc36_row3_col10 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_6cc36_row4_col4 {
#   background-color: #fd7e38;
#   color: #f1f1f1;
# }
# #T_6cc36_row4_col7 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_6cc36_row5_col1 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_6cc36_row5_col9 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_6cc36_row6_col6 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_6cc36_row7_col4 {
#   background-color: #fedd7e;
#   color: #000000;
# }
# #T_6cc36_row7_col7 {
#   background-color: #fb4b29;
#   color: #f1f1f1;
# }
# #T_6cc36_row8_col8 {
#   background-color: #f84528;
#   color: #f1f1f1;
# }
# #T_6cc36_row9_col0 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_6cc36_row9_col5 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_6cc36_row9_col9 {
#   background-color: #ee3122;
#   color: #f1f1f1;
# }
# #T_6cc36_row10_col2 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_6cc36_row10_col3 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_6cc36_row10_col10 {
#   background-color: #ed3022;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6cc36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cc36_level0_col0" class="col_heading level0 col0" >actor</th>
#       <th id="T_6cc36_level0_col1" class="col_heading level0 col1" >composer</th>
#       <th id="T_6cc36_level0_col2" class="col_heading level0 col2" >film</th>
#       <th id="T_6cc36_level0_col3" class="col_heading level0 col3" >journalist</th>
#       <th id="T_6cc36_level0_col4" class="col_heading level0 col4" >lawyer</th>
#       <th id="T_6cc36_level0_col5" class="col_heading level0 col5" >music</th>
#       <th id="T_6cc36_level0_col6" class="col_heading level0 col6" >painter</th>
#       <th id="T_6cc36_level0_col7" class="col_heading level0 col7" >politician</th>
#       <th id="T_6cc36_level0_col8" class="col_heading level0 col8" >priest</th>
#       <th id="T_6cc36_level0_col9" class="col_heading level0 col9" >singer</th>
#       <th id="T_6cc36_level0_col10" class="col_heading level0 col10" >writer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cc36_level0_row0" class="row_heading level0 row0" >actor</th>
#       <td id="T_6cc36_row0_col0" class="data row0 col0" >1.505575</td>
#       <td id="T_6cc36_row0_col1" class="data row0 col1" >0.012125</td>
#       <td id="T_6cc36_row0_col2" class="data row0 col2" >0.169485</td>
#       <td id="T_6cc36_row0_col3" class="data row0 col3" >0.005766</td>
#       <td id="T_6cc36_row0_col4" class="data row0 col4" >0.001507</td>
#       <td id="T_6cc36_row0_col5" class="data row0 col5" >0.018771</td>
#       <td id="T_6cc36_row0_col6" class="data row0 col6" >0.002143</td>
#       <td id="T_6cc36_row0_col7" class="data row0 col7" >0.000643</td>
#       <td id="T_6cc36_row0_col8" class="data row0 col8" >0.000178</td>
#       <td id="T_6cc36_row0_col9" class="data row0 col9" >0.136057</td>
#       <td id="T_6cc36_row0_col10" class="data row0 col10" >0.011858</td>
#     </tr>
#     <tr>
#       <th id="T_6cc36_level0_row1" class="row_heading level0 row1" >composer</th>
#       <td id="T_6cc36_row1_col0" class="data row1 col0" >0.007037</td>
#       <td id="T_6cc36_row1_col1" class="data row1 col1" >0.981730</td>
#       <td id="T_6cc36_row1_col2" class="data row1 col2" >0.008455</td>
#       <td id="T_6cc36_row1_col3" class="data row1 col3" >0.000277</td>
#       <td id="T_6cc36_row1_col4" class="data row1 col4" >0.000301</td>
#       <td id="T_6cc36_row1_col5" class="data row1 col5" >0.093855</td>
#       <td id="T_6cc36_row1_col6" class="data row1 col6" >0.001578</td>
#       <td id="T_6cc36_row1_col7" class="data row1 col7" >0.000152</td>
#       <td id="T_6cc36_row1_col8" class="data row1 col8" >0.000565</td>
#       <td id="T_6cc36_row1_col9" class="data row1 col9" >0.093353</td>
#       <td id="T_6cc36_row1_col10" class="data row1 col10" >0.003292</td>
#     </tr>
#     <tr>
#       <th id="T_6cc36_level0_row2" class="row_heading level0 row2" >film</th>
#       <td id="T_6cc36_row2_col0" class="data row2 col0" >0.046482</td>
#       <td id="T_6cc36_row2_col1" class="data row2 col1" >0.044800</td>
#       <td id="T_6cc36_row2_col2" class="data row2 col2" >1.141243</td>
#       <td id="T_6cc36_row2_col3" class="data row2 col3" >0.006348</td>
#       <td id="T_6cc36_row2_col4" class="data row2 col4" >0.000402</td>
#       <td id="T_6cc36_row2_col5" class="data row2 col5" >0.007765</td>
#       <td id="T_6cc36_row2_col6" class="data row2 col6" >0.001445</td>
#       <td id="T_6cc36_row2_col7" class="data row2 col7" >0.000137</td>
#       <td id="T_6cc36_row2_col8" class="data row2 col8" >0.000059</td>
#       <td id="T_6cc36_row2_col9" class="data row2 col9" >0.004876</td>
#       <td id="T_6cc36_row2_col10" class="data row2 col10" >0.008392</td>
#     </tr>
#     <tr>
#       <th id="T_6cc36_level0_row3" class="row_heading level0 row3" >journalist</th>
#       <td id="T_6cc36_row3_col0" class="data row3 col0" >0.005583</td>
#       <td id="T_6cc36_row3_col1" class="data row3 col1" >0.005749</td>
#       <td id="T_6cc36_row3_col2" class="data row3 col2" >0.026785</td>
#       <td id="T_6cc36_row3_col3" class="data row3 col3" >0.983117</td>
#       <td id="T_6cc36_row3_col4" class="data row3 col4" >0.025798</td>
#       <td id="T_6cc36_row3_c
